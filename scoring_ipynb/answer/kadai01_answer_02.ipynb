# %% [markdown]
# # 課題

# %% [raw]
# 名前:student2  学籍番号:2

# %% [markdown]
# ## 問1
# `print()` を用いて「Hello World!」と出力

# %%
# 解答欄
# print()
s = "Hello World!"
print(s)
# Out:
# Hello World!

# %% [markdown]
# ## 問2
# $10!$ を計算し，結果を`print()`で出力

# %%
# 解答欄
def factorial(n):
    if n == 1:
        return 1
    return n * factorial(n - 1)
print(factorial(10))
# Out:
# 3628800

# %% [markdown]
# ## 評価
# ### 点数

# %%
合計得点: 3点
Q1 答えが合っている : 1点
Q1 print関数が使われている : 1点
Q2 答えが合っている : 1点
Q2 mathモジュールが使われている : 0点

# %% [markdown]
# ### コメント
