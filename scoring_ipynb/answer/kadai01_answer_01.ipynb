# %% [markdown]
# # 課題

# %% [raw]
# 名前:student1  学籍番号:1

# %% [markdown]
# ## 問1
# `print()` を用いて「Hello World!」と出力

# %%
# 解答欄
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## 問2
# $10!$ を計算し，結果を`print()`で出力

# %%
# 解答欄
import math
print(math.factorial(10))
# Out:
# 3628800

# %% [markdown]
# ## 評価
# ### 点数

# %% [markdown]
# ### コメント
